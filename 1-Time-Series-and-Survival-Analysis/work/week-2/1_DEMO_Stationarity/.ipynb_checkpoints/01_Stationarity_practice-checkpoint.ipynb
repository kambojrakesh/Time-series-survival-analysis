# %%
import sys, os
import statsmodels as ss
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
#os.chdir('data')
from colorsetup import colors, palette
sns.set_palette(palette)

# %%
# reproducibility
np.random.seed(42)
# data
time = np.arange(100)
#time

# %%
stationary = np.random.normal(loc=0, scale=1.0, size=len(time))
#stationary

# %%
def run_sequence_plot(x, y, title, xlabel="time", ylabel="series"):
    plt.plot(x, y, 'k-')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(alpha=0.3);

# %%
run_sequence_plot(time, stationary, 
                  title="Stationary TS")

# %%
# seed to start series
seed = 3.14

# create autocorrelated data
lagged = np.empty_like(time, dtype='float')
for t in time:
    lagged[t] = seed + np.random.normal(loc=0, scale=2.5, size=1)
    seed = lagged[t]

# %%
run_sequence_plot(time, lagged,
                  title="Nonstationary Data w/Lagged Structure")

# %%
trend = (time * 2.75) + stationary
run_sequence_plot(time, trend,
                  title="Nonstationary Data w/Trend")

# %%
# reproducibility
np.random.seed(1234)

# data
level_1 = np.random.normal(loc=0, scale=1.0, size = 50)
level_2 = np.random.normal(loc=0, scale=10.0, size = 50)
heteroscedasticity = np.append(level_1, level_2)
heteroscedasticity
run_sequence_plot(time, heteroscedasticity,
                  title="Nonstationary Data w/Heteroscedasticity")
# Out:
# array([ 4.71435164e-01, -1.19097569e+00,  1.43270697e+00, -3.12651896e-01,
#        -7.20588733e-01,  8.87162940e-01,  8.59588414e-01, -6.36523504e-01,
#         1.56963721e-02, -2.24268495e+00,  1.15003572e+00,  9.91946022e-01,
#         9.53324128e-01, -2.02125482e+00, -3.34077366e-01,  2.11836468e-03,
#         4.05453412e-01,  2.89091941e-01,  1.32115819e+00, -1.54690555e+00,
#        -2.02646325e-01, -6.55969344e-01,  1.93421376e-01,  5.53438911e-01,
#         1.31815155e+00, -4.69305285e-01,  6.75554085e-01, -1.81702723e+00,
#        -1.83108540e-01,  1.05896919e+00, -3.97840228e-01,  3.37437654e-01,
#         1.04757857e+00,  1.04593826e+00,  8.63717292e-01, -1.22091575e-01,
#         1.24712954e-01, -3.22794806e-01,  8.41674713e-01,  2.39096052e+00,
#         7.61995878e-02, -5.66445930e-01,  3.61419367e-02, -2.07497760e+00,
#         2.47792200e-01, -8.97156784e-01, -1.36794833e-01,  1.82891913e-02,
#         7.55413982e-01,  2.15268581e-01,  8.41008795e+00, -1.44581008e+01,
#        -1.40197328e+01, -1.00918200e+00, -5.48242449e+00, -1.44619508e+00,
#         3.54020332e+00, -3.55130253e-01,  5.65738306e+00,  1.54565880e+01,
#        -9.74236334e+00, -7.03448771e-01,  3.07968855e+00, -2.08498763e+00,
#         1.03380073e+01, -2.40045363e+01,  2.03060362e+01, -1.14263129e+01,
#         2.11883387e+00,  7.04720624e+00, -7.85435212e+00,  4.62059737e+00,
#         7.04228225e+00,  5.23507968e+00, -9.26254314e+00,  2.00784295e+01,
#         2.26962542e+00, -1.15265911e+01,  6.31979446e+00,  3.95126867e-01,
#         4.64392325e+00, -3.56351666e+01,  1.32110562e+01,  1.52630552e+00,
#         1.64529543e+00, -4.30095691e+00,  7.67368736e+00,  9.84919842e+00,
#         2.70835849e+00,  1.39198619e+01,  7.98423130e-01, -3.99964581e+00,
#        -1.02785056e+01, -5.84718211e+00,  8.16593927e+00, -8.19470518e-01,
#        -3.44766014e+00,  5.28288145e+00, -1.06898878e+01, -5.11881309e+00])
